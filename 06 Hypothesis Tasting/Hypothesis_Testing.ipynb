# %% [markdown]
# # 06 Hypothesis Testing - KARAN JOLIYA

# %% [markdown]
# Bombay hospitality Ltd. operates a franchise model for producing exotic Norwegian dinners throughout New England. The operating cost for a franchise in a week (W) is given by the equation W =  1,000+ 5X, where X represents the number of units produced in a week. Recent feedback from restaurant owners suggests that this cost model may no longer be accurate, as their observed weekly operating costs are higher.

# %% [markdown]
# ##### Objective:
# - To investigate the restaurant owners' claim about the increase in weekly operating costs using hypothesis testing.
# - Data Provided:
#     - The theoretical weekly operating cost model: W =  1,000+ 5X
#     - Sample of 25 restaurants with a mean weekly cost of Rs. 3,050
#     - Number of units produced in a week (X) follows a normal distribution with a mean (μ) of 600 units and a standard deviation (σ) of 25 units

# %% [markdown]
# ## Assignment Tasks:

# %% [markdown]
# ###### The restaurant owners claim that the weekly operating costs are higher than the theoretical cost model.
# ###### Therefore, a right-tailed hypothesis test is used.
#
# - Null Hypothesis (Ho):
#     - [ H_0 : \mu \le 4000 ]
#     - The mean weekly operating cost is less than or equal to Rs. 4,000 as predicted by the model
#     - ( W = 1000 + 5X ) for ( X = 600 ).
#
# - Alternative Hypothesis (H₁):
#     - [ H_1 : \mu > 4000 ]
#     - The mean weekly operating cost is greater than Rs. 4,000, supporting the restaurant owners’ claim.
#
#     - Significance Level:
#     - [ \alpha = 0.05 ]

# %%
import math #Import libraries 
from scipy.stats import norm

# %%
# Sample information
sample_mean = 3050    # x̄ = Rs. 3050
n = 25               # sample size

# Production information
X_mean = 600            # mean units produced
sigma_X = 25             # standard deviation of X

# Cost model: W = 1000 + 5X
mu = 1000 + 5 * X_mean  # theoretical mean weekly cost
sigma = 5 * sigma_X     # standard deviation of weekly cost

alpha = 0.05    # significance level

# 1. HYPOTHESES
# H0: μ ≤ 4000  (Weekly operating cost is not higher than the model)
# H1: μ > 4000  (Weekly operating cost is higher than the model)


# 2. TEST STATISTIC (Z-test)
z_statistic = (sample_mean - mu) / (sigma / math.sqrt(n))

# 3. PROBABILITY (p-value)

# Right-tailed test
p_value = 1 - norm.cdf(z_statistic)


# 4. CRITICAL VALUE METHOD
z_critical = norm.ppf(1 - alpha)

print("Theoretical Mean Weekly Cost (μ):", mu)
print("Z-Test Statistic:", round(z_statistic, 4))
print("Critical Z-Value:", round(z_critical, 4))
print("P-value:", round(p_value, 4))
# Out:
# Theoretical Mean Weekly Cost (μ): 4000
# Z-Test Statistic: -38.0
# Critical Z-Value: 1.6449
# P-value: 1.0

# %%
if z_statistic > z_critical:
    print("\nDecision: Reject the Null Hypothesis")
    print("Conclusion: There is strong evidence that weekly operating costs")
    print("are higher than the theoretical cost model suggests.")
else:
    print("\nDecision: Fail to Reject the Null Hypothesis")
    print("Conclusion: There is insufficient evidence to support the claim")
    print("that weekly operating costs are higher than the model.")
# Out:
# Decision: Fail to Reject the Null Hypothesis
# Conclusion: There is insufficient evidence to support the claim
# that weekly operating costs are higher than the model.
