# %% [markdown]
# # 20 RNN - KARAN JOLIYA

# %% [markdown]
# ## Monthly Milk Production Forecasting (Using RNN, LSTM, and GRU Deep Learning Models)

# %% [markdown]
# ### Step 1: Identify the Business Problem
# #### From the file name monthly_milk_production.csv, it is clear that this dataset showing the monthly milk production of a dairy farm or industry.
# #### Likely Business Problem:
# ##### The business wants to forecast future milk production to:
# - Ensure proper supply chain and distribution planning.
# - Manage inventory and storage efficiently.
# - Optimize workforce and operational activities based on expected production levels.
# - Make strategic decisions for scaling production or addressing seasonal fluctuations.

# %% [markdown]
# ### Step 2: Define the Objective
# #### Objective Statement:
# The objective is to develop a time series forecasting model that accurately predicts the monthly milk production for the upcoming months. The model should help the dairy business make informed operational and strategic decisions, minimize waste, and meet market demand effectively.

# %% [markdown]
# ### Assignment Tasks
# #### 1.	Exploratory Data Analysis (EDA)
# - Visualize trends, seasonality, and anomalies in the milk production data.
# - Check for any missing values or outliers.
# - Normalize or scale the data for neural network models.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore') # ignore warnings

df = pd.read_csv("monthly_milk_production.csv")
df.head()
# Out:
#       Date  Production
# 0  1962-01         589
# 1  1962-02         561
# 2  1962-03         640
# 3  1962-04         656
# 4  1962-05         727

# %%
df.info() #info about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        168 non-null    object
#  1   Production  168 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.8+ KB

# %%
df["Date"] = pd.to_datetime(df["Date"]) #correct dtypes

# %%
df.isnull().sum()  #check null values
# Out:
# Date          0
# Production    0
# dtype: int64

# %%
df.set_index("Date", inplace=True) #set index

# %%
df.duplicated().sum() # check duplicates
# Out:
# np.int64(26)

# %%
df.drop_duplicates(inplace = True) # drop duplicates

# %%
# Exploratory Data Analysis (EDA)
# Visualize trends, seasonality, and anomalies in the milk production data.
plt.figure(figsize=(12,5))
plt.plot(df, label="Milk Production")
plt.title("Monthly Milk Production Trend")
plt.xlabel("Month")
plt.ylabel("Milk Production")
plt.legend()
plt.show()

# %%
# Outlier Check
plt.figure()
plt.boxplot(df["Production"])
plt.title("Outlier Detection")
plt.show()

# %%
# Normalize or scale the data for neural network models.
from sklearn.preprocessing import MinMaxScaler
import numpy as np

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)

# %% [markdown]
# ### 2.	Data Preparation for Deep Learning
# - Create input-output sequences (time windows) suitable for training RNNs/LSTMs/GRUs.
# - Split data into training, validation, and test sets.
# - Reshape data for model input dimensions.

# %%
# Create input-output sequences (time windows) suitable for training RNNs/LSTMs/GRUs.
def create_sequences(data, window=12):
    X, y = [], []
    for i in range(len(data) - window):
        X.append(data[i:i+window])
        y.append(data[i+window])
    return np.array(X), np.array(y)

WINDOW_SIZE = 12
X, y = create_sequences(scaled_data, WINDOW_SIZE)

# %%
# Train-Test Split
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
# reshape data for input
X_train = X_train.reshape(X_train.shape[0], WINDOW_SIZE, 1)
X_test = X_test.reshape(X_test.shape[0], WINDOW_SIZE, 1)

# %% [markdown]
# ### 3.	Model Building
# - Build three separate models:
#     - Basic RNN
#     - LSTM
#     - GRU
# - Tune hyperparameters (e.g., window size, number of units, batch size, epochs).
# - Use appropriate loss functions and optimizers.

# %%
# Model 1: Basic RNN
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, GRU

rnn_model = Sequential()
rnn_model.add(SimpleRNN(50, activation="relu", input_shape=(WINDOW_SIZE, 1)))
rnn_model.add(Dense(1))

rnn_model.compile(optimizer="adam", loss="mse")

print("\nTraining RNN Model...")
rnn_model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=1)
# Out:
# Training RNN Model...
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2262
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1331
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0612
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0280
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0249
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0188
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0184
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0160
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0142
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0131
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0120
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0121
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0104
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0099
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0092
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0085
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0085
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0079
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0073
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0073
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0067
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0068
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0059
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0054
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0055
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0054
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0047
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0045
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0044
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0043
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0043
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0042
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0041
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0043
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0042
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0043

# %%
# Model 2: LSTM

lstm_model = Sequential()
lstm_model.add(LSTM(64, activation="relu", input_shape=(WINDOW_SIZE, 1)))
lstm_model.add(Dense(1))

lstm_model.compile(optimizer="adam", loss="mse")

print("\nTraining LSTM Model...")
lstm_model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=1)
# Out:
# Training LSTM Model...
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2132
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1464
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0769
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0296
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0327
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0246
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0268
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0233
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0242
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0232
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0227
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0222
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0218
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0216
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0211
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0208
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0206
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0201
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0200
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0197
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0191
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0189
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0184
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0178
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0178
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0170
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0164
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0163
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0157
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0150
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0152
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0148
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0138
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0144
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0132
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0126
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0123
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0127
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0124
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0117
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0115
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0108
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0109
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0114
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0112
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0108
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0103
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0108
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0103
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0099

# %%
# Model 3: GRU
gru_model = Sequential()
gru_model.add(GRU(64, activation="relu", input_shape=(WINDOW_SIZE, 1)))
gru_model.add(Dense(1))

gru_model.compile(optimizer="adam", loss="mse")

print("\nTraining GRU Model...")
gru_model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=1)
# Out:
# Training GRU Model...
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2833
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2049
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1429
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0901
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0503
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0299
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0319
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0275
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0276
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0262
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0259
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0256
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0244
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0246
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0242
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0233
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0228
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0226
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0219
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0216
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0224
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0211
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0210
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0206
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0197
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0194
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0191
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0189
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0185
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0177
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0174
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0168
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0166
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0162
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0152
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0150
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0146
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0138
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0134
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0146
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0147
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0144
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0135
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0124
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0133
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0131
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0116
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0109
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0115

# %% [markdown]
# ### 4.	Model Evaluation
# - Plot predictions vs. actual values.
# - Calculate forecasting metrics: RMSE, MAE, MAPE.
# - Compare the performance of RNN, LSTM, and GRU.

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
#Calculate forecasting metrics: RMSE, MAE, MAPE.
def evaluate_model(model, X_test, y_test):
    predictions = model.predict(X_test)
    predictions = scaler.inverse_transform(predictions)
    actual = scaler.inverse_transform(y_test)

    rmse = np.sqrt(mean_squared_error(actual, predictions))
    mae = mean_absolute_error(actual, predictions)

    return rmse, mae, predictions, actual
rnn_rmse, rnn_mae, rnn_pred, actual = evaluate_model(rnn_model, X_test, y_test)
lstm_rmse, lstm_mae, lstm_pred, _ = evaluate_model(lstm_model, X_test, y_test)
gru_rmse, gru_mae, gru_pred, _ = evaluate_model(gru_model, X_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step

# %%
#Compare the performance of RNN, LSTM, and GRU.
print("\n===== MODEL PERFORMANCE =====")
print("RNN RMSE:", rnn_rmse, " MAE:", rnn_mae)
print("LSTM RMSE:", lstm_rmse, " MAE:", lstm_mae)
print("GRU RMSE:", gru_rmse, " MAE:", gru_mae)
# Out:
# ===== MODEL PERFORMANCE =====
# RNN RMSE: 29.26754627470091  MAE: 22.043539193960324
# LSTM RMSE: 41.43632701989031  MAE: 29.999741774338936
# GRU RMSE: 48.40961175234088  MAE: 40.48454402043267

# %%
# Plot predictions vs. actual values.
plt.figure(figsize=(12,5))
plt.plot(actual, label="Actual")
plt.plot(lstm_pred, label="LSTM Prediction")
plt.title("LSTM Predictions vs Actual")
plt.legend()
plt.show()

# %% [markdown]
# ### 5.	Prediction and Visualization
# - Forecast milk production for the next 12 months.
# - Visualize the predicted trend with uncertainty or confidence intervals if possible.

# %%
# Forecast Next 12 Months
future_input = scaled_data[-WINDOW_SIZE:]
future_predictions = []

for i in range(12):
    pred = lstm_model.predict(future_input.reshape(1, WINDOW_SIZE, 1))
    future_predictions.append(pred[0])
    future_input = np.append(future_input[1:], pred)

future_predictions = scaler.inverse_transform(future_predictions)
# Out:
# WARNING:tensorflow:5 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001B192C8E2A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %%
future_dates = pd.date_range(start=df.index[-1], periods=12, freq="M") #Create Future Dates

# %%
#  Plot Forecast
plt.figure(figsize=(12,5))
plt.plot(df, label="Historical Data")
plt.plot(future_dates, future_predictions, label="12 Month Forecast", color="red")
plt.title("Milk Production Forecast")
plt.legend()
plt.show()

# %%
# Print Forecast Results
forecast_df = pd.DataFrame({
    "Month": future_dates,
    "Predicted Milk Production": future_predictions.flatten()
})

print("\n===== 12 MONTH FORECAST =====")
print(forecast_df)
# Out:
# ===== 12 MONTH FORECAST =====
#         Month  Predicted Milk Production
# 0  1975-12-31                 836.406288
# 1  1976-01-31                 865.153757
# 2  1976-02-29                 901.904579
# 3  1976-03-31                 939.448015
# 4  1976-04-30                 968.493725
# 5  1976-05-31                 959.844870
# 6  1976-06-30                 926.837379
# 7  1976-07-31                 868.756598
# 8  1976-08-31                 836.364285
# 9  1976-09-30                 834.660460
# 10 1976-10-31                 856.922310
# 11 1976-11-30                 888.933044

# %% [markdown]
# ### 6.	Business Insights
# #### Interpret results and recommend how the dairy business can use these forecasts for better planning and resource allocation.

# %% [markdown]
# ##### The forecasting results show a clear seasonal pattern and steady growth in milk production. The LSTM model provides the most accurate predictions among RNN, LSTM, and GRU.
# ##### Using these forecasts, the dairy business can:
# - Plan storage and distribution during peak production months.
# - Schedule workforce and operations efficiently.
# - Avoid overproduction or shortages.
# - Make better budgeting and expansion decisions based on expected future demand.
# ##### Overall, the forecasting model helps the company improve planning, reduce waste, and allocate resources more effectively.
